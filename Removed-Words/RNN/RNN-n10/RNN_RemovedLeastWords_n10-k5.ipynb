# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/labeled_twitter_depressive_full_clean_km2.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123984 entries, 0 to 123983
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   text            123984 non-null  object
#  1   depression      123984 non-null  float64
#  2   not_depression  123984 non-null  float64
#  3   cluster         123984 non-null  int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.8+ MB

# %%
print(df.isnull().sum().sum())
print(df.isna().sum().sum())
print(df.duplicated().sum().sum())
# Out:
# 0
# 0
# 786

# %%
np.where(df['text'].isnull())[0]
# Out:
# array([], dtype=int64)

# %%
duplicates = df[df.duplicated(keep=False)]
duplicates_index = duplicates.index.tolist()
print("Índices de instancias duplicadas:")
print(duplicates_index)
# Out:
# Índices de instancias duplicadas:
# [10, 26, 33, 80, 188, 376, 400, 570, 904, 1123, 1133, 1139, 1356, 1577, 1758, 1844, 1886, 1945, 1954, 1988, 2197, 2287, 2297, 2360, 2466, 2693, 2701, 2744, 2753, 2770, 2865, 2907, 2985, 3000, 3110, 3241, 3253, 3296, 3379, 3443, 3444, 3457, 3472, 3511, 3541, 3672, 3720, 3901, 3907, 3915, 4122, 4375, 4407, 4520, 4547, 4551, 4681, 4799, 4830, 4852, 4859, 4992, 5003, 5159, 5262, 5272, 5683, 5801, 5917, 5980, 5998, 6060, 6230, 6242, 6446, 6655, 6657, 6695, 6705, 6773, 6816, 6850, 6903, 7077, 7124, 7235, 7263, 7383, 7641, 7854, 7984, 8039, 8140, 8186, 8207, 8463, 8510, 8569, 8811, 8872, 8907, 8978, 9030, 9077, 9265, 9275, 9284, 9310, 9326, 9369, 9392, 9539, 9608, 9646, 9650, 9798, 9845, 10037, 10141, 10227, 10733, 10761, 10825, 11075, 11198, 11229, 11284, 11292, 11333, 11507, 11594, 11660, 11740, 11750, 11776, 11895, 12285, 12298, 12475, 12742, 12773, 12965, 13077, 13080, 13082, 13084, 13094, 13263, 13340, 13392, 13399, 13431, 13795, 13997, 14000, 14002, 14027, 14073, 14074, 14152, 14286, 14374, 14382, 14489, 14526, 14566, 14589, 14634, 14747, 14789, 14850, 14934, 15065, 15107, 15231, 15354, 15374, 15446, 15468, 15552, 15604, 15634, 15751, 15791, 15876, 15908, 15942, 16492, 16527, 16554, 16598, 16699, 16743, 16754, 16771, 16967, 16968, 17008, 17095, 17150, 17202, 17210, 17255, 17257, 17653, 17671, 17768, 17776, 17777, 17795, 17870, 17891, 17937, 18085, 18120, 18122, 18268, 18507, 18776, 18780, 18790, 18891, 19013, 19066, 19071, 19157, 19187, 19190, 19192, 19206, 19254, 19261, 19275, 19347, 19420, 19454, 19539, 19564, 19594, 19728, 19814, 19822, 19867, 19875, 19897, 19937, 19945, 19997, 20023, 20087, 20136, 20145, 20193, 20225, 20443, 20470, 20599, 20833, 21171, 21187, 21253, 21293, 21383, 21402, 21744, 21790, 22036, 22055, 22112, 22380, 22435, 22438, 22571, 22606, 22857, 23122, 23230, 23259, 23268, 23317, 23713, 23953, 24029, 24089, 24211, 24554, 24576, 24886, 25042, 25085, 25088, 25125, 25126, 25195, 25309, 25439, 25661, 25688, 25763, 25822, 25915, 25941, 26335, 26653, 26681, 26949, 27382, 27731, 27822, 27826, 27830, 27876, 27963, 27975, 27980, 28269, 28360, 28601, 28727, 28741, 28800, 28835, 28859, 28895, 28988, 29205, 29314, 29570, 29613, 29680, 29698, 29701, 30279, 30282, 30426, 30429, 30787, 30790, 30955, 30986, 31005, 31432, 31552, 31558, 31704, 31714, 31847, 31918, 31935, 32048, 32098, 32123, 32210, 32330, 32473, 32700, 32736, 32930, 33172, 33247, 33257, 33396, 33582, 33752, 33772, 33891, 33909, 33981, 34118, 34312, 34371, 34382, 34468, 34513, 34557, 34603, 34672, 34719, 34730, 34754, 35077, 35151, 35184, 35543, 35559, 35675, 35764, 35830, 35870, 35881, 35917, 36094, 36139, 36147, 36309, 36511, 36564, 36701, 36813, 36818, 36854, 37159, 37167, 37322, 37363, 37541, 37571, 37585, 37687, 37696, 37760, 37835, 37868, 37929, 37951, 38282, 38351, 38378, 38467, 38525, 38807, 39017, 39211, 39301, 39348, 39452, 39477, 39480, 39541, 39545, 39747, 39834, 39845, 40185, 40194, 40625, 40867, 41242, 41445, 41504, 41651, 41807, 42005, 42104, 42176, 42200, 42503, 42567, 42593, 42637, 42947, 43075, 43212, 43507, 44576, 44580, 44769, 44805, 44825, 44851, 44858, 44870, 44871, 44877, 44918, 45014, 45068, 45315, 45328, 45661, 46052, 46113, 46198, 46345, 46479, 46484, 46537, 46704, 46836, 46910, 46919, 47025, 47092, 47458, 47640, 47649, 47965, 48238, 48445, 48680, 48736, 48922, 49248, 49289, 49880, 50057, 50154, 50207, 51074, 51265, 51323, 51588, 51729, 51775, 51861, 51865, 51911, 51986, 52174, 52345, 52381, 52405, 52416, 52574, 52921, 53064, 53065, 53193, 53539, 53635, 53765, 53876, 53877, 53891, 53907, 54065, 54122, 54162, 54250, 54355, 54428, 54457, 54463, 54894, 54969, 55243, 55398, 55507, 55622, 55627, 55666, 55808, 55888, 55912, 55924, 56081, 56087, 56274, 56379, 56432, 56540, 56623, 56638, 56649, 56714, 56916, 57296, 57412, 57427, 57500, 57595, 57778, 57824, 57859, 57942, 57955, 57985, 57987, 58001, 58007, 58080, 58196, 58277, 58317, 58340, 58359, 58537, 58563, 58877, 58897, 58901, 58977, 58992, 59083, 59203, 59281, 59453, 59472, 59493, 59634, ...

# %%
print(df['text'][26])
print(df['text'][33])
# Out:
# india
# india

# %%
df = df.drop(['depression', 'not_depression'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123984 entries, 0 to 123983
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   text     123984 non-null  object
#  1   cluster  123984 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.9+ MB

# %%
df.groupby('cluster').count()
# Out:
#           text
# cluster
# 0        70509
# 1        53475

# %%
classes = df.cluster.unique()
counts = []

for i in classes:
  count = len(df[df.cluster==i])
  counts.append(count)

plt.bar(['Not-Depression', 'Depression'], counts)
plt.show()

# %%
def tweet_cleaner(text, remove_words):
  # removing k words
  words = text.split()
  filter_text = [word for word in words if word not in remove_words]

  text = ' '.join(filter_text)
  return text

# %%
df['text'][126]
# Out:
# 'hi airindia cancelled tickets air india customer care executive confirmed call cancelled tickets upon request sent email ecommerce response could help check'

# %%
# K words to remove
remove_w = {'come', 'country', 'gonna', 'days', 'india'}

df['text'] = df['text'].apply(lambda x: tweet_cleaner(x, remove_w))

# %%
df['text'][126]
# Out:
# 'hi airindia cancelled tickets air customer care executive confirmed call cancelled tickets upon request sent email ecommerce response could help check'

# %%
print(df.isnull().sum().sum())
print(df.isna().sum().sum())
print(df.duplicated().sum().sum())
# Out:
# 0
# 0
# 829

# %%
np.where(df['text'].isnull())[0]
# Out:
# array([], dtype=int64)

# %%
duplicates_two = df[df.duplicated(keep=False)]
duplicates_index_two = duplicates_two.index.tolist()
print("Índices de instancias duplicadas:")
print(duplicates_index_two)
# Out:
# Índices de instancias duplicadas:
# [10, 26, 33, 80, 188, 376, 400, 483, 570, 747, 904, 1123, 1133, 1139, 1338, 1356, 1577, 1758, 1808, 1844, 1886, 1945, 1954, 1988, 2038, 2197, 2287, 2297, 2320, 2360, 2466, 2540, 2693, 2701, 2744, 2753, 2770, 2865, 2907, 2985, 3000, 3110, 3241, 3253, 3269, 3296, 3379, 3443, 3444, 3457, 3472, 3511, 3541, 3606, 3611, 3649, 3672, 3720, 3901, 3907, 3915, 4122, 4375, 4407, 4520, 4547, 4551, 4681, 4799, 4800, 4830, 4852, 4859, 4992, 5003, 5159, 5262, 5272, 5648, 5683, 5801, 5825, 5917, 5979, 5980, 5998, 6060, 6230, 6242, 6446, 6655, 6657, 6695, 6705, 6773, 6816, 6850, 6903, 6992, 7077, 7124, 7162, 7235, 7263, 7383, 7636, 7641, 7854, 7984, 8039, 8140, 8186, 8207, 8463, 8510, 8569, 8811, 8872, 8907, 8978, 9030, 9077, 9265, 9275, 9284, 9310, 9326, 9369, 9392, 9539, 9608, 9646, 9650, 9798, 9845, 10037, 10141, 10227, 10733, 10761, 10825, 11075, 11198, 11229, 11284, 11292, 11333, 11507, 11594, 11660, 11740, 11750, 11776, 11895, 12285, 12298, 12475, 12742, 12773, 12965, 13077, 13080, 13082, 13084, 13094, 13263, 13340, 13392, 13399, 13431, 13795, 13997, 14000, 14002, 14027, 14073, 14074, 14152, 14286, 14374, 14382, 14489, 14526, 14566, 14589, 14634, 14747, 14789, 14850, 14934, 15065, 15107, 15231, 15354, 15374, 15446, 15468, 15552, 15604, 15634, 15751, 15791, 15876, 15908, 15942, 16492, 16527, 16554, 16598, 16699, 16743, 16754, 16771, 16967, 16968, 17008, 17095, 17150, 17202, 17210, 17255, 17257, 17653, 17671, 17702, 17768, 17776, 17777, 17795, 17870, 17891, 17937, 18085, 18120, 18122, 18268, 18507, 18776, 18780, 18790, 18891, 19013, 19066, 19071, 19157, 19187, 19190, 19192, 19206, 19254, 19261, 19275, 19347, 19420, 19454, 19539, 19564, 19594, 19728, 19814, 19822, 19867, 19875, 19897, 19937, 19945, 19997, 20023, 20087, 20136, 20145, 20193, 20225, 20443, 20470, 20599, 20833, 21132, 21171, 21187, 21253, 21293, 21383, 21402, 21744, 21790, 22036, 22055, 22112, 22380, 22435, 22438, 22571, 22606, 22857, 23122, 23230, 23259, 23268, 23317, 23713, 23953, 24029, 24089, 24211, 24554, 24568, 24576, 24886, 25042, 25085, 25088, 25125, 25126, 25195, 25210, 25309, 25439, 25661, 25688, 25763, 25822, 25915, 25941, 26335, 26653, 26681, 26949, 27382, 27731, 27822, 27826, 27830, 27876, 27963, 27975, 27980, 28269, 28360, 28601, 28727, 28741, 28800, 28835, 28859, 28895, 28988, 29205, 29314, 29570, 29613, 29680, 29698, 29701, 30279, 30282, 30426, 30429, 30787, 30790, 30955, 30986, 31005, 31432, 31552, 31558, 31704, 31714, 31847, 31918, 31935, 32048, 32098, 32123, 32210, 32330, 32473, 32700, 32736, 32930, 33172, 33247, 33257, 33396, 33582, 33752, 33772, 33891, 33909, 33981, 34118, 34312, 34371, 34382, 34468, 34513, 34557, 34603, 34672, 34719, 34730, 34754, 35077, 35151, 35184, 35543, 35559, 35675, 35764, 35830, 35870, 35881, 35917, 36094, 36139, 36147, 36309, 36511, 36564, 36701, 36813, 36818, 36854, 37159, 37167, 37322, 37363, 37541, 37571, 37585, 37687, 37696, 37760, 37835, 37868, 37929, 37951, 38282, 38351, 38378, 38467, 38525, 38807, 39017, 39211, 39301, 39348, 39452, 39477, 39480, 39541, 39545, 39747, 39834, 39845, 40185, 40194, 40625, 40867, 41242, 41445, 41504, 41651, 41807, 42005, 42104, 42176, 42200, 42503, 42567, 42593, 42637, 42947, 43075, 43212, 43507, 44576, 44580, 44769, 44805, 44825, 44851, 44858, 44870, 44871, 44877, 44918, 45014, 45068, 45315, 45328, 45661, 46052, 46113, 46198, 46345, 46479, 46484, 46537, 46704, 46836, 46910, 46919, 47025, 47092, 47458, 47640, 47649, 47965, 48238, 48445, 48680, 48736, 48922, 49248, 49289, 49880, 50057, 50154, 50207, 51074, 51265, 51323, 51588, 51729, 51775, 51861, 51865, 51911, 51986, 52174, 52345, 52381, 52405, 52416, 52574, 52921, 53064, 53065, 53193, 53539, 53635, 53765, 53876, 53877, 53891, 53907, 54065, 54122, 54162, 54250, 54355, 54428, 54457, 54463, 54894, 54969, 55243, 55398, 55507, 55622, 55627, 55666, 55808, 55888, 55912, 55924, 56081, 56087, 56274, 56335, 56379, 56432, 56540, 56590, 56623, 56638, 56649, 56714, 56916, 57296, 57412, 57427, 57500, 57595, 57778, 57824, 57859, 57942, 57955, 57985, 57987, 58001 ...

# %%
print(df['text'][26])
print(df['text'][33])

# %%
df_filter_duplicates = df.drop_duplicates(keep='first')

# %%
df_filter_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123155 entries, 0 to 123983
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   text     123155 non-null  object
#  1   cluster  123155 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ MB

# %%
print(df_filter_duplicates.isnull().sum().sum())
print(df_filter_duplicates.isna().sum().sum())
print(df_filter_duplicates.duplicated().sum().sum())
# Out:
# 0
# 0
# 0

# %%
np.where(df_filter_duplicates['text'].isnull())[0]
# Out:
# array([], dtype=int64)

# %%
duplicates_three = df_filter_duplicates[df_filter_duplicates.duplicated(keep=False)]
duplicates_index_three = duplicates_three.index.tolist()
print("Índices de instancias duplicadas:")
print(duplicates_index_three)
# Out:
# Índices de instancias duplicadas:
# []

# %%
df_filter_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123155 entries, 0 to 123983
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   text     123155 non-null  object
#  1   cluster  123155 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ MB

# %% [markdown]
# # Word Count

# %%
# Function to count words in an instance
def word_count(text):
    return len(text.split())

# %%
df_text = pd.DataFrame(df_filter_duplicates['text'])

# Add a column with the number of words
df_filter_duplicates['num_palabras'] = df_text['text'].apply(word_count)

# Finding the minimum word length
min_palabras = df_filter_duplicates['num_palabras'].min()
print(min_palabras)

# Find all instance with the minimum number of words and save the indices
min_indices = df_filter_duplicates[df_filter_duplicates['num_palabras'] == min_palabras].index
print(min_indices)
# Out:
# 0
# Index([26, 1844], dtype='int64')
# <ipython-input-25-da73c64e6850>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter_duplicates['num_palabras'] = df_text['text'].apply(contar_palabras)

# %%
df_filter_duplicates['text'][26]
# Out:
# ''

# %%
df_filter_duplicates['text'][1844]
# Out:
# ''

# %%
# Delete rows with the found indexes
df_filter = df_filter_duplicates.drop(min_indices)

print("\nÍndices eliminados:")
print(min_indices.tolist())
# Out:
# Índices eliminados:
# [26, 1844]

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123153 entries, 0 to 123983
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   text          123153 non-null  object
#  1   cluster       123153 non-null  int64
#  2   num_palabras  123153 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.8+ MB

# %%
df_filter.groupby('cluster').count()
# Out:
#           text  num_palabras
# cluster
# 0        69959         69959
# 1        53194         53194

# %%
df_filter = df_filter.drop(['num_palabras'], axis=1)
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123153 entries, 0 to 123983
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   text     123153 non-null  object
#  1   cluster  123153 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ MB

# %%
df_filter.tail(10)
# Out:
#                                                      text  cluster
# 123974                           personal liberty granted        0
# 123975                                 unprecedented step        0
# 123976  shahmahmoodqureshi said reports backing state ...        0
# 123977  military spokesman claimed evidence indian int...        0
# 123978                                         mind heart        0
# 123979  unification ttp breakaway factions jua hua aug...        1
# 123980  happydiwali dgisi dgispr real face exposed tod...        0
# 123981  anybody know website ships pre order bts seaso...        0
# 123982  hinted weeks back interview today presented ev...        0
# 123983  slice pakistan national security advisor world...        1

# %%
df_filter.index = pd.RangeIndex(len(df_filter.index))

# %%
df_filter.to_csv("labeled_twitter_RNN_km2_Exp-10w_remove-5-words_SHAP-LIME_improve.csv", index=False)

# %%
data = pd.read_csv('labeled_twitter_RNN_km2_Exp-10w_remove-5-words_SHAP-LIME_improve.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123153 entries, 0 to 123152
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   text     123153 non-null  object
#  1   cluster  123153 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.9+ MB

# %%
data.tail(10)
# Out:
#                                                      text  cluster
# 123143                           personal liberty granted        0
# 123144                                 unprecedented step        0
# 123145  shahmahmoodqureshi said reports backing state ...        0
# 123146  military spokesman claimed evidence indian int...        0
# 123147                                         mind heart        0
# 123148  unification ttp breakaway factions jua hua aug...        1
# 123149  happydiwali dgisi dgispr real face exposed tod...        0
# 123150  anybody know website ships pre order bts seaso...        0
# 123151  hinted weeks back interview today presented ev...        0
# 123152  slice pakistan national security advisor world...        1

# %%
print(data.isnull().sum().sum())
print(data.isna().sum().sum())
print(data.duplicated().sum().sum())
# Out:
# 0
# 0
# 0
